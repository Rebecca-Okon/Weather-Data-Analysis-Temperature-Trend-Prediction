# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
df_climate = pd.read_csv("synthetic_climate_data.csv", parse_dates=['Date'])
df
# Out:
#                       Date         Region  Temperature (Celsius)  \
# 0      2013-01-01 00:00:00         Africa              14.496714
# 1      2013-01-01 01:00:00  South America              13.865322
# 2      2013-01-01 02:00:00  South America              14.654861
# 3      2013-01-01 03:00:00           Asia              15.533789
# 4      2013-01-01 04:00:00           Asia              13.780192
# ...                    ...            ...                    ...
# 87595  2022-12-29 19:00:00        Oceania              14.025531
# 87596  2022-12-29 20:00:00         Europe              14.419652
# 87597  2022-12-29 21:00:00           Asia              15.080537
# 87598  2022-12-29 22:00:00         Europe              14.524719
# 87599  2022-12-29 23:00:00         Global              14.028825
#
#        Anomaly (Celsius)
# 0               1.126022
# 1               0.139308
# 2               2.786966
# 3              -0.051807
# 4              -0.568722
# ...                  ...
# ...

# %%
# Resample to daily data for global temperature
df_global = df_climate[df_climate['Region'] == 'Global']
df_global.set_index('Date', inplace=True)
#df_global_resampled = df_global.resample('D').mean()  # Resample to daily data

# %%
# Plot global temperature trend over the past decade
plt.figure(figsize=(10, 6))
plt.plot(df_global_resampled.index, df_global_resampled['Temperature (Celsius)'], label='Global Temperature')
plt.title('Global Temperature Trend Over the Past Decade')
plt.xlabel('Year')
plt.ylabel('Temperature (Celsius)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Plot global temperature trend over the past decade
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.plot(df_global_resampled.index, df_global_resampled['Temperature (Celsius)'], label='Global Temperature')
#       4 plt.title('Global Temperature Trend Over the Past Decade')
#       5 plt.xlabel('Year')
#
# NameError: name 'df_global_resampled' is not defined
